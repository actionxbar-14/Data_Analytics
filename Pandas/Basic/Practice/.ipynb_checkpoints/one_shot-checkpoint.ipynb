# %%
# install pandas

# %%
# !pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.9 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.9 MB 962.7 kB/s eta 0:00:10
#    -- ------------------------------------- 0.5/9.9 MB 962.7 kB/s eta 0:00:10
#    --- ------------------------------------ 0.8/9.9 MB 988.9 kB/s eta 0:00:10
#    ----- ---------------------------------- 1.3/9.9 MB 1.1 MB/s eta 0:00:08
#    ------ --------------------------------- 1.6/9.9 MB 1.2 MB/s eta 0:00:08
#    ------- -------------------------------- 1.8/9.9 MB 1.2 MB/s eta 0:00:07
#    -------- ------------------------------- 2.1/9.9 MB 1.3 MB/s eta 0:00:07
#    --------- ------------------------------ 2.4/9.9 MB 1.3 MB/s eta 0:00:06
#    ---------- ----------------------------- 2.6/9.9 MB 1.3 MB/s eta 0:00:06
#    ----------- ---------------------------- 2.9/9.9 MB 1.3 MB/s eta 0:00:06
# ...

# %%
# import pandas 

import pandas as pd

# %%
pd.__version__
# Out:
# '3.0.3'

# %%
#Dataframe : tables ko dataframe kahte hai :

# %%
# Topics :

# %% [markdown]
# #

# %%
# 1. Create Dataframe:

# %%
# 2. Basic Dataframe Understanding

# %%
#3. Save and Load data from csv

# %%
# 4. Rows & Columns - Selection

# %%
# 5. Filter dataframe

# %%
# 6. Rows & Columns - Operation ( Add , update , delete)

# %%
# 7. Working with date value

# %%
# 8. Handelling missing values

# %%
# 9. Aggregation and group by

# %%
# 10. Concatenate and Merge Dataframe ( JOINS )

# %%
# 11. AI and ChatGPT
