# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\ANUBHAV\OneDrive\Documents\My Data Sources\JOB_Simulation\BFSI_Data_Gathering_Job_Simulation\Customers.csv")
print(df)
# Out:
#      customer_id first_name last_name date_of_birth  gender       city  \
# 0          10001     Naveen      Rana    2003-11-21    Male      Kochi
# 1          10002       Anil    Saxena    1955-08-01    Male     Jaipur
# 2          10003     Naveen      Nair    1979-12-06    Male  Ahmedabad
# 3          10004      Vinod   Agarwal    1963-04-28    Male      Noida
# 4          10005     Nikhil     Sinha    1978-09-24     NaN      Surat
# ..           ...        ...       ...           ...     ...        ...
# 497        10498     Anjali      Kaur    1960-04-08  Female    Kolkata
# 498        10499      Tarun     Sinha    1959-05-09    Male      Delhi
# 499        10500      Vivek     Kumar    1975-10-06    Male      Patna
# 500        10363       Usha  Malhotra    1970-08-14  Female     Mumbai
# 501        10078     Ramesh    Kapoor    1972-11-26    Male     Nagpur
#
#              state customer_since
# 0           Kerala     2023-05-10
# 1        Rajasthan     2023-07-06
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 502 entries, 0 to 501
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   customer_id     502 non-null    int64
#  1   first_name      502 non-null    str
#  2   last_name       502 non-null    str
#  3   date_of_birth   502 non-null    str
#  4   gender          494 non-null    str
#  5   city            499 non-null    str
#  6   state           502 non-null    str
#  7   customer_since  502 non-null    str
# dtypes: int64(1), str(7)
# memory usage: 31.5 KB
