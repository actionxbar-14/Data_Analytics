# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'C:\Users\ANUBHAV\Data_Analytics\DAP\EDA\Datasets\train (1).csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# # Why do EDA :
#
#  - Model building.
#  - Analysis and reporting.
#  - Validate assumptions.
#  - Handelling missing values.
#  - feature engineering.
#  - detecting outliers.
#
#
# # NOTE:
# - EDA is an iterative process.

# %% [markdown]
# # STEP : 1
# - Define the column type.
# - group them in three different catogeries.
#
# --> Numerical : Age , Fare , PassengerId .
#
#
# --> Categorical : Survived , Pclass , Sex , SibSp ,Parch , Embarked
#
#
# --> Mixed : Name , Ticket , Cabin.

# %% [markdown]
# # STEP : 2
#
#  -- > :: Performed given Operations :
# [ These operations are performed multiple times in loop untill you reached final conclusions ].
#
#
# 1. Univariate Analysis.
# 2. Bivariate Analysis.
# 3. Multivariate Analysis.
# 4. Feature Engineering.
# 5. Finding Outliers.
# 6. Handelling missing Values.

# %% [markdown]
# # 1. Univariate Analysis :
#
# -- Univariate analysis focuses on analyzing each feature(Column) in the dataset independently.
#
# -> **Distribution analysis**: The distribution of each feature is examined to identify its shape, central tendency, and dispersion.
#
# -> **Identifying potential issues**: Univariate analysis helps in identifying potential problems with the data such as outliers, skewness, and missing values.
#
#
#
#
#
#
# #### The shape of a data distribution refers to its overall pattern or form as it is represented on a graph. Some common shapes of data distributions include:
#
# - **Normal Distribution**: A symmetrical and bell-shaped distribution where the mean, median, and mode are equal and the majority of the data falls in the middle of the distribution with gradually decreasing frequencies towards the tails.
#
# - **Skewed Distribution**: A distribution that is not symmetrical, with one tail being longer than the other. It can be either positively skewed (right-skewed) or negatively skewed (left-skewed).
#
# - **Bimodal Distribution**: A distribution with two peaks or modes.
#
# - **Uniform Distribution**: A distribution where all values have an equal chance of occurring.
#
# The shape of the data distribution is important in identifying the presence of outliers, skewness, and the type of statistical tests and models that can be used for further analysis.

# %% [markdown]
# ## Steps of doing the univariate analysis on Numerical analysis :

# %% [markdown]
# ### Age Column :
#
#
#
#
#
#
# ** Conclusions ** :
#
# 1. Age is normally(almost) distributed,
# 2. 20% of the values are missing,
# 3. There are some outliers.

# %%
df['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
df['Age'].plot(kind = 'hist' , bins = 20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Age'].plot(kind = 'kde')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df['Age'].plot(kind = 'kde')
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\plotting\_core.py:1185, in PlotAccessor.__call__(self, *args, **kwargs)
#    1182             label_name = label_kw or data.columns
#    1183             data.columns = label_name
# -> 1185 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plt.draw_if_interactive()
#      73 return plot_obj.result
#
# ...

# %%
# normal distribution : 

df['Age'].skew()

# %%
# box plot : tells us about the outliers. 


df['Age'].plot(kind = 'box')

# %%
df[df['Age']  > 65 ]

# %%
# checking the missing values in age column : 

df['Age'].isnull().sum()  #--> 177

df['Age'].isnull().sum() / len(df['Age'])

# %% [markdown]
# ### Fare Column:
#
#
# ** Conclusions** :
#
# 1. The data is highly postively skewed.
# 2. Fare column actually contain the group fare and not the individual fare ( this might be an issue ).
# 3. We need to perform the feature Engineering and create a new column called individual fare.

# %%
df['Fare'].describe()

# %%
df['Fare'].plot(kind = 'hist')

# %%
df['Age'].plot(kind = 'kde')

# %%
# checking skewness : 

df['Fare'].skew()  #--> 4.787 [ highly positivly skewwed ] 

#--> we have to carefull while performing the stastical analysis!

# %%
# Checking outliers : 

df['Fare'].plot(kind = 'box')

# %%
df[df['Fare'] > 250 ]

# %%
df['Fare'].isnull().sum()

# %% [markdown]
# ## Steps of doing the univariate analysis on categorical analysis :

# %% [markdown]
# ### Survived :
#
#
# :--> Conclusions :

# %%
df['Survived'].value_counts()

# %%
df['Survived'].value_counts().plot(kind = 'bar')

# %%
df['Survived'].value_counts().plot(kind = 'pie' , autopct = '%0.1f%%')

# %%
df['Survived'].isnull().sum()

# %% [markdown]
# ### Pclass :
#
#
# :--> Conclusions :
#
# --> Generally the hirarchy is that more chepaer the price of ticket is , the more number of people may travelled in that particular class, but
# --> in the analysis the 1 class traveller is slighltly more than second class traveller.

# %%
df['Pclass'].value_counts()

# %%
df['Pclass'].value_counts().plot(kind = 'bar')

# %%
df['Pclass'].value_counts().plot(kind = 'pie' , autopct = '%0.1f%%')

# %%
df['Survived'].isnull().sum()

# %% [markdown]
# ### Sex :
#
#
# :--> Conclusions :

# %%
df['Sex'].value_counts()

# %%
df['Sex'].value_counts().plot(kind = 'bar')

# %%
df['Sex'].value_counts().plot(kind = 'pie' , autopct = '%0.1f%%')

# %%
df['Sex'].isnull().sum()

# %% [markdown]
# ### SibSp :
#
# :--> Conclusions :
#
# --> Parch and Sibsp cols can be merged to form a new col family_size.
# --> Create a new col called is_alone.

# %%
df['SibSp'].value_counts()

# %%
df['SibSp'].value_counts().plot(kind = 'bar')

# %%
df['SibSp'].value_counts().plot(kind = 'pie' , autopct = '%0.0000001f%%')

# %% [markdown]
# ### Parch :
#
# --> Conclusions :

# %%
df['Parch'].value_counts()

# %%
df['Parch'].value_counts().plot(kind = 'bar')

# %%
df['Parch'].value_counts().plot(kind = 'pie' , autopct = '%0.0000001f%%')

# %% [markdown]
# ### Embarked :
#
# :--> Conclusions :

# %%
df['Embarked'].value_counts()

# %%
df['Embarked'].value_counts().plot(kind = 'bar')

# %%
df['Embarked'].value_counts().plot(kind = 'pie' , autopct = '%0.0000001f%%')

# %% [markdown]
# ## Steps of Doing Univariate Analysis on Mixed Columns :

# %%
# NOTE :-->  We need to perform feature engineering to do Univariate analysis on the mixed type columns.

# %% [markdown]
# # 2. Bivariate Analysis :
#
# - Select 2 cols.
#
# - Understand type of relationship :--
#
#
#     1. **Numerical - Numerical** :-
#         a. You can plot graphs like scatterplot(regression plots), 2D histplot, 2D KDEplots.
#         b. Check correlation coefficent to check linear relationship.
#
#
#     2. **Numerical - Categorical** :  create visualizations that compare the distribution of the numerical data across different categories of the categorical data.
#         a. You can plot graphs like barplot, boxplot, kdeplot violinplot even scatterplots.
#
#
#     3. **Categorical - Categorical** :
#         a. You can create cross-tabulations or contingency tables that show the distribution of values in one categorical column, grouped by the values in the other categorical column.
#         b. You can plots like heatmap, stacked barplots, treemaps.
#
# - Write your conclusions.

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# NOTE : 
# - Because analysis survival model prr based hai isliye ham survived column ke around hi bivariate analysis krenge  , isliye sabse pahle
#   survived column ke saare combination with catagorical columns mai ham bivariate analysis krenge :

# %% [markdown]
# ## Performing bivariate analysis on the two important table 'Pclass' and 'survived' :

# %%
# :--> Pclass v/s Survived in terms of Numbers : 


pd.crosstab(df['Survived'] , df ['Pclass'])

# %%
# :--> Pclass v/s Survived in terms of percentage : 


pd.crosstab(df['Survived'] , df ['Pclass'] , normalize = 'columns')*100

# %%
# :--> Pclass v/s Survived representing heatmap :

sns.heatmap(pd.crosstab(df['Survived'] , df ['Pclass'] , normalize = 'columns')*100 )

# %% [markdown]
# ## Performing bivariate analysis on the two important table 'Sex' and 'survived' :

# %%
# :--> Sex v/s Survived in terms of Numbers : 


pd.crosstab(df['Survived'] , df ['Sex'])

# %%
# :--> Sex v/s Survived in terms of Percentage : 


pd.crosstab(df['Survived'] , df ['Pclass'] , normalize = 'columns')*100

# %%
# :--> Sex v/s Survived representing heatmap :

sns.heatmap(pd.crosstab(df['Survived'] , df ['Sex'] , normalize = 'columns')*100 )

# %% [markdown]
# ## Performing bivariate analysis on the two important table 'Embarked' and 'survived' :

# %%
# :--> Embarked v/s Survived in terms of Numbers : 


pd.crosstab(df['Survived'] , df ['Embarked'])

# %%
# :--> Embarked v/s Survived in terms of Percentage : 

pd.crosstab(df['Survived'] , df ['Embarked'] , normalize = 'columns')*100

# %%
# :--> Embarked v/s Survived representing heatmap :

sns.heatmap(pd.crosstab(df['Survived'] , df ['Embarked'] , normalize = 'columns')*100 )

# %% [markdown]
# ## Performing bivariate analysis on the two important table 'Embarked' and 'Sex' :

# %%
# :--> Embarked v/s Sex in terms of Numbers : 


pd.crosstab(df['Sex'] , df ['Embarked'])

# %%
# :--> Embarked v/s Survived in terms of Percentage : 

pd.crosstab(df['Sex'] , df ['Embarked'] , normalize = 'columns')*100

# %%
# :--> Embarked v/s Sex representing heatmap :

sns.heatmap(pd.crosstab(df['Sex'] , df ['Embarked'] , normalize = 'columns')*100 )

# %% [markdown]
# ## Performing bivariate analysis on the two important table 'Embarked' and 'Pclass' :

# %%
# :--> Embarked v/s Pclass in terms of Numbers : 


pd.crosstab(df['Pclass'] , df ['Embarked'])
# Out:
# Embarked   C   Q    S
# Pclass
# 1         85   2  127
# 2         17   3  164
# 3         66  72  353

# %%
# :--> Embarked v/s Pclass in terms of Percentage : 

pd.crosstab(df['Sex'] , df ['Embarked'] , normalize = 'columns')*100
# Out:
# Embarked          C          Q          S
# Sex
# female    43.452381  46.753247  31.521739
# male      56.547619  53.246753  68.478261

# %%
# :--> Embarked v/s Pclass representing heatmap :

sns.heatmap(pd.crosstab(df['Pclass'] , df ['Embarked'] , normalize = 'columns')*100 )
# Out:
# <Axes: xlabel='Embarked', ylabel='Pclass'>

# %%
# NOTE : 
# - Because analysis survival model prr based hai isliye ham survived column ke around hi bivariate analysis krenge  , isliye sabse pahle
#   survived column ke saare combination with Numerical Columns columns mai ham bivariate analysis krenge :

# %% [markdown]
# ## Performing Bivariate Anlaysis between survived and age :

# %%
df[df['Survived'] == 1]['Age'].plot(kind = 'kde' , label = 'Survived')
df[df['Survived'] == 0]['Age'].plot(kind = 'kde' , label = 'Not Survived') 

plt.legend()
plt.show()

# %%
df[df['Pclass'] == 1]['Age'].mean()
# Out:
# np.float64(38.233440860215055)

# %% [markdown]
# ## : : Feature Engineering on Fare Col :

# %%
df['SibSp'].value_counts()
# Out:
# SibSp
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64

# %%
df[df['SibSp'] == 8]
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 159          160         0       3         Sage, Master. Thomas Henry    male
# 180          181         0       3       Sage, Miss. Constance Gladys  female
# 201          202         0       3                Sage, Mr. Frederick    male
# 324          325         0       3           Sage, Mr. George John Jr    male
# 792          793         0       3            Sage, Miss. Stella Anna  female
# 846          847         0       3           Sage, Mr. Douglas Bullen    male
# 863          864         0       3  Sage, Miss. Dorothy Edith "Dolly"  female
#
#      Age  SibSp  Parch    Ticket   Fare Cabin Embarked
# 159  NaN      8      2  CA. 2343  69.55   NaN        S
# 180  NaN      8      2  CA. 2343  69.55   NaN        S
# 201  NaN      8      2  CA. 2343  69.55   NaN        S
# 324  NaN      8      2  CA. 2343  69.55   NaN        S
# 792  NaN      8      2  CA. 2343  69.55   NaN        S
# ...

# %%
df1 = pd.read_csv(r'C:\Users\ANUBHAV\Data_Analytics\DAP\EDA\Datasets\test.csv')

# %%
df = pd.concat([df ,df1])

# %%
df[df['Ticket'] == 'CA. 2343']
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 159          160       0.0       3         Sage, Master. Thomas Henry    male
# 180          181       0.0       3       Sage, Miss. Constance Gladys  female
# 201          202       0.0       3                Sage, Mr. Frederick    male
# 324          325       0.0       3           Sage, Mr. George John Jr    male
# 792          793       0.0       3            Sage, Miss. Stella Anna  female
# 846          847       0.0       3           Sage, Mr. Douglas Bullen    male
# 863          864       0.0       3  Sage, Miss. Dorothy Edith "Dolly"  female
# 188         1080       NaN       3                    Sage, Miss. Ada  female
# 342         1234       NaN       3              Sage, Mr. John George    male
# 360         1252       NaN       3        Sage, Master. William Henry    male
# 365         1257       NaN       3     Sage, Mrs. John (Annie Bullen)  female
#
# ...

# %%
df[df['Ticket'] == 'CA. 2343']
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 159          160       0.0       3         Sage, Master. Thomas Henry    male
# 180          181       0.0       3       Sage, Miss. Constance Gladys  female
# 201          202       0.0       3                Sage, Mr. Frederick    male
# 324          325       0.0       3           Sage, Mr. George John Jr    male
# 792          793       0.0       3            Sage, Miss. Stella Anna  female
# 846          847       0.0       3           Sage, Mr. Douglas Bullen    male
# 863          864       0.0       3  Sage, Miss. Dorothy Edith "Dolly"  female
# 188         1080       NaN       3                    Sage, Miss. Ada  female
# 342         1234       NaN       3              Sage, Mr. John George    male
# 360         1252       NaN       3        Sage, Master. William Henry    male
# 365         1257       NaN       3     Sage, Mrs. John (Annie Bullen)  female
#
# ...

# %%
df['Ticket'].value_counts()
# Out:
# Ticket
# CA. 2343              11
# CA 2144                8
# 1601                   8
# 347082                 7
# 347077                 7
#                       ..
# 365237                 1
# 347086                 1
# A.5. 3236              1
# SOTON/O.Q. 3101262     1
# 359309                 1
# Name: count, Length: 929, dtype: int64

# %%
df['individual_fare'] = df['Fare'] / (df['SibSp'] + df['Parch'] + 1)

# %%
df[['individual_fare' ,'Fare']].describe()
# Out:
#        individual_fare         Fare
# count      1308.000000  1308.000000
# mean         20.518215    33.295479
# std          35.774337    51.758668
# min           0.000000     0.000000
# 25%           7.452767     7.895800
# 50%           8.512483    14.454200
# 75%          24.237500    31.275000
# max         512.329200   512.329200

# %%
df['individual_fare'].plot(kind = 'box')
# Out:
# <Axes: >

# %%
df['family_size'] =  df['SibSp'] + df['Parch'] + 1

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# family_type : 

# 1 --> alone
# 2 - 4 --> small 
# > 5   --> large

def transform_family_size(num):

    if num == 1:
        return 'alone' 
    elif num > 1 and num < 5:
        return 'small' 
    else:
        return 'large'

# %%
df['family_type'] = df['family_size'].apply(transform_family_size)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## Performing Bivariate analysis between survived and newly created family_type column :

# %%
df = df.reset_index(drop=True)

pd.crosstab(
    df['Survived'],
    df['family_type'],
    normalize='columns'
) * 100
# Out:
# family_type      alone      large      small
# Survived
# 0.0          69.646182  83.870968  42.123288
# 1.0          30.353818  16.129032  57.876712

# %%
df['surname'] = df['Name'].str.split(',').str.get(0)

# %%
df
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...

# %%
df['title'] = df['Name'].str.split(',').str.get(1).str.strip().str.split(' ').str.get(0)

# %%
df['title'].value_counts()
# Out:
# title
# Mr.          757
# Miss.        260
# Mrs.         197
# Master.       61
# Rev.           8
# Dr.            8
# Col.           4
# Ms.            2
# Major.         2
# Mlle.          2
# Don.           1
# Mme.           1
# Lady.          1
# Sir.           1
# Capt.          1
# the            1
# Jonkheer.      1
# Dona.          1
# Name: count, dtype: int64
